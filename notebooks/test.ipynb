# %%
import urllib.request
import cv2

# %%
url = "http://answers.opencv.org/upfiles/logo_2.png" # replace with the actual URL of the image you want to read in

# %%
import urllib.request
import cv2
import numpy as np

# %%
def chinese_to_english(prompt: str) -> str:

    prompt = f"Translate the following Chinese into English: {prompt}"

    response = openai.Completion.create(
        model="text-davinci-003",
        prompt=prompt,
        temperature=0.5,
        max_tokens=500,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
    )

    ans = response.choices[0]["text"]

    return ans


def url_to_image(url: str) -> np.ndarray:

    # Download the image using urllib
    with urllib.request.urlopen(url) as url_response:
        img_array = bytearray(url_response.read())

    # Convert the byte array to a numpy array for use with OpenCV
    img = cv2.imdecode(np.asarray(img_array), cv2.IMREAD_UNCHANGED)

    # Return the image as a numpy array
    return img


def text_to_img(prompt: str) -> np.ndarray:
    response = openai.Image.create(
        prompt=prompt,
        n=1,
        size="1024x1024"
    )
    image_url = response['data'][0]['url']
    image = url_to_image(image_url)

    return image

# %%
import openai

openai.api_key = "ENTER_API_KEY_HERE"

# %%
img = text_to_img("a mouse is singing")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
